# %% [markdown]
# ## Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load the data

# %%
dataset = pd.read_csv('../dataset/POSTFIRE_MASTER_DATA_SHARE_2064760709534146017.csv')
# Out:
# C:\Users\manzi\AppData\Local\Temp\ipykernel_9968\2688485602.py:1: DtypeWarning: Columns (12,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('../dataset/POSTFIRE_MASTER_DATA_SHARE_2064760709534146017.csv')

# %%
dataset
# Out:
#         OBJECTID          * Damage  * Street Number    * Street Name  \
# 0              1         No Damage           8376.0     Quail Canyon
# 1              2   Affected (1-9%)           8402.0     Quail Canyon
# 2              3         No Damage           8430.0    Quail Canyon
# 3              4         No Damage           3838.0      Putah Creek
# 4              5         No Damage           3830.0      Putah Creek
# ...          ...               ...              ...              ...
# 130718    131856  Destroyed (>50%)          19355.0    Pacific Coast
# 130719    131857  Destroyed (>50%)            922.0         Hartzell
# 130720    131858   Affected (1-9%)            815.0        Las Lomas
# 130721    131859   Affected (1-9%)           3233.0  Rambla Pacifico
# 130722    131860   Affected (1-9%)          18102.0       Sandy Cape
#
#        * Street Type (e.g. road, drive, lane, etc.)  \
# 0                                              Road
# ...
